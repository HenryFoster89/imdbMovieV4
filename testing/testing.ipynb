# %% [markdown]
# qui sto facendo del testing utilizzando gli script della cartella testing

# %%
from testing.reading_urls import testing_speed
from utils.db_connection import get_connection_pyodbc, get_connection_alchemy
from utils.config import *
import pandas as pd
import polars as pl

engine = get_connection_alchemy()

# %%
#dfPandas, dfPolars = testing_speed()

# %%
URL = "https://datasets.imdbws.com/title.ratings.tsv.gz"

dfPolars = pl.read_csv(URL , separator="\t", quote_char = """""")
dfPolars.write_csv(os.path.join("title_ratings.csv"))


# # Carica i dati nella tabella name_basics
# dfPandas.to_sql("title_ratings", engine, if_exists="replace", index=False)

# %%
dfPolars.sort("averageRating")
# Out:
# shape: (1_535_911, 3)
# ┌───────────┬───────────────┬──────────┐
# │ tconst    ┆ averageRating ┆ numVotes │
# │ ---       ┆ ---           ┆ ---      │
# │ str       ┆ f64           ┆ i64      │
# ╞═══════════╪═══════════════╪══════════╡
# │ tt0011470 ┆ 1.0           ┆ 23       │
# │ tt0015520 ┆ 1.0           ┆ 15       │
# │ tt0016535 ┆ 1.0           ┆ 22       │
# │ tt0017656 ┆ 1.0           ┆ 18       │
# │ tt0018608 ┆ 1.0           ┆ 15       │
# │ …         ┆ …             ┆ …        │
# │ tt9727708 ┆ 10.0          ┆ 5        │
# │ tt9805198 ┆ 10.0          ┆ 15       │
# │ tt9805258 ┆ 10.0          ┆ 5        │
# │ tt9866444 ┆ 10.0          ┆ 8        │
# │ tt9889628 ┆ 10.0          ┆ 5        │
# └───────────┴───────────────┴──────────┘

# %%
dfPolars.isnull()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 dfPolars.isnull()
#
# AttributeError: 'DataFrame' object has no attribute 'isnull'

# %%
dfPandas
# Out:
#              nconst         primaryName birthYear deathYear  \
# 0         nm0000001        Fred Astaire      1899      1987
# 1         nm0000002       Lauren Bacall      1924      2014
# 2         nm0000003     Brigitte Bardot      1934        \N
# 3         nm0000004        John Belushi      1949      1982
# 4         nm0000005      Ingmar Bergman      1918      2007
# ...             ...                 ...       ...       ...
# 14195115  nm9993714   Romeo del Rosario        \N        \N
# 14195116  nm9993716       Essias Loberg        \N        \N
# 14195117  nm9993717  Harikrishnan Rajan        \N        \N
# 14195118  nm9993718         Aayush Nair        \N        \N
# 14195119  nm9993719          Andre Hill        \N        \N
#
#                             primaryProfession  \
# 0                actor,miscellaneous,producer
# 1          actress,soundtrack,archive_footage
# 2           actress,music_department,producer
# 3               actor,writer,music_department
# ...

# %%
# Caricamento del file TSV in un DataFrame
df = pd.read_csv(r"data\name_basics.tsv", sep="\t", encoding="utf-8")
# Sostituzione dei NaN con None (che diventa NULL in SQL Server)
df.replace(r'\\N', '1', regex=True, inplace=True)
df.fillna("NULL")
df["primaryName"] = df["primaryName"].fillna("NULL").astype(str)
# Bisogna studiare bene quali valori non piacciono a sql manager (e ai suoi tipi e capire come gestirli)
# sicuramente ho fatto un po' di confusione qui sopra
# Out:
#              nconst         primaryName birthYear deathYear  \
# 0         nm0000001        Fred Astaire      1899      1987
# 1         nm0000002       Lauren Bacall      1924      2014
# 2         nm0000003     Brigitte Bardot      1934         1
# 3         nm0000004        John Belushi      1949      1982
# 4         nm0000005      Ingmar Bergman      1918      2007
# ...             ...                 ...       ...       ...
# 14195115  nm9993714   Romeo del Rosario         1         1
# 14195116  nm9993716       Essias Loberg         1         1
# 14195117  nm9993717  Harikrishnan Rajan         1         1
# 14195118  nm9993718         Aayush Nair         1         1
# 14195119  nm9993719          Andre Hill         1         1
#
#                             primaryProfession  \
# 0                actor,miscellaneous,producer
# 1          actress,soundtrack,archive_footage
# 2           actress,music_department,producer
# 3               actor,writer,music_department
# ...

# %%
# df.to_csv(r"data\name_basicsV2.tsv", sep="\t", encoding="utf-8")

# tentativo di crewazione di un file V2 da dare al bulk insert

# %%
import pandas as pd
from sqlalchemy import create_engine

# Definisci la connessione con SQLAlchemy
server = DB_SERVER
database = DB_NAME

engine = create_engine(f"mssql+pyodbc://{server}/{database}?trusted_connection=yes&driver=ODBC+Driver+17+for+SQL+Server")

# Carica i dati nella tabella name_basics
df.to_sql("name_basics", engine, if_exists="append", index=False)

# ci ha messo 14 minuti, qeusto funziona utilizznado le modifiche sopra.
# Out:
# C:\Users\enric\AppData\Local\Temp\ipykernel_3664\2343951645.py:14: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df.to_sql("name_basics",
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# File c:\Users\enric\anaconda3\envs\analisi_p\Lib\site-packages\pandas\io\sql.py:2672, in SQLiteDatabase.execute(self, sql, params)
#    2671 try:
# -> 2672     cur.execute(sql, *args)
#    2673     return cur
#
# ProgrammingError: ('42S02', "[42S02] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Il nome di oggetto 'sqlite_master' non è valido. (208) (SQLExecDirectW); [42S02] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Impossibile preparare le istruzioni. (8180)")
#
# ...
